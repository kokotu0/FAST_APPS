# %%
from sqlmodel import distinct, select
from core.database import get_session
from models.ProductModels import Product, ProductOption


with get_session() as session:
  print(session.exec(select((Product)).
                     where(Product.deleted == False)).all())
# Out:
# [Product(created_by=0, updated_at=datetime.datetime(2025, 11, 3, 16, 15, 40, 927644), channel_type=380, channel=0, product_name='어쩌구저쩌구', image=None, large=90, medium=None, idx=77, created_at=datetime.datetime(2025, 11, 3, 12, 5, 53, 583697), updated_by=0, external_product_id='12313', product_code='1121313', base_description='', small=None, deleted=False)]
